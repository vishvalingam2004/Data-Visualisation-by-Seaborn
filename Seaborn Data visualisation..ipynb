# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('50ulke.csv')

# %%
display(ds)
# Out:
#     Rankings                 Countries  National Income     2023  Growth  \
# 0          1             United States         20412.87  24537.0    2.27
# 1          2                     China         14092.51  21574.0    6.86
# 2          3                     Japan          5167.05   5962.0    1.71
# 3          4                   Germany          4211.64   5272.0    2.51
# 4          5            United Kingdom          2936.29   3477.0    1.79
# 5          6                    France          2925.10   3586.0    1.85
# 6          7                     India          2848.23   4663.0    6.74
# 7          8                     Italy          2181.97   2554.0    1.47
# 8          9                    Brazil          2138.92   2717.0    0.98
# 9         10                    Canada          1798.51   2434.0    3.00
# 10        11                    Russia          1719.90   1974.0    1.55
# 11        12                     Korea          1693.25   2155.0    3.09
# ...

# %%
ds.shape
# Out:
# (50, 8)

# %%
ds.columns
# Out:
# Index(['Rankings', 'Countries', 'National Income', '2023', 'Growth',
#        'Per person', '2. Rankings', 'Continent'],
#       dtype='object')

# %%
sns.scatterplot(data=ds,x=ds['National Income'],y=ds['Countries'],hue=ds['Continent'])
plt.title("INCOME ANALYSIS")
# Out:
# Text(0.5, 1.0, 'INCOME ANALYSIS')

# %%
sns.scatterplot(data=ds,x=ds['2023'],y=ds['Countries'],hue=ds['Continent'])
# Out:
# <AxesSubplot:xlabel='2023', ylabel='Countries'>

# %%
sns.scatterplot(data=ds,x=ds['Per person'],y=ds['Countries'],hue=ds['Continent'])
# Out:
# <AxesSubplot:xlabel='Per person', ylabel='Countries'>

# %%
sns.histplot(x=ds['Per person'],color='green')
plt.title("PER PERSON ANALYSIS")
# Out:
# Text(0.5, 1.0, 'PER PERSON ANALYSIS')

# %%
sns.histplot(x=ds['2023'],color='orange')
plt.title("YEAR 2023 ANALYSIS")
# Out:
# Text(0.5, 1.0, 'YEAR 2023 ANALYSIS')

# %%
sns.histplot(x=ds['Growth'],color='red')
plt.title("GROWTH ANALYSIS")
# Out:
# Text(0.5, 1.0, 'GROWTH ANALYSIS')

# %%
sns.distplot(x=ds['National Income'],color='blue')
plt.title("NATIONAL GROWTH INCOME ANALYSIS")
# Out:
# C:\Users\Kumaran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'NATIONAL GROWTH INCOME ANALYSIS')

# %%
sns.histplot(x=ds['National Income'],color='blue')
plt.title("NATIONAL GROWTH INCOME ANALYSIS")
# Out:
# Text(0.5, 1.0, 'NATIONAL GROWTH INCOME ANALYSIS')

# %%
ds['Countries'].value_counts()
# Out:
# United States               1
# Singapore                   1
# Norway                      1
# Islamic Republic of Iran    1
# United Arab Emirates        1
# Nigeria                     1
# Ireland                     1
# Israel                      1
# South Africa                1
# Denmark                     1
# Malaysia                    1
# Hong Kong SAR               1
# Philippines                 1
# China                       1
# Colombia                    1
# Pakistan                    1
# Finland                     1
# Bangladesh                  1
# Chile                       1
# Egypt                       1
# Czech Republic              1
# Portugal                    1
# Romania                     1
# Vietnam                     1
# Austria                     1
# Thailand                    1
# Belgium                     1
# Sweden                      1
# Japan                       1
# Germany                     1
# United Kingdom              1
# ...

# %%
ds['Continent'].value_counts()
# Out:
# Asia             19
# Europe           19
# South America     5
# North America     3
# Africa            3
# Oceania           1
# Name: Continent, dtype: int64

# %%
sns.countplot(x=ds['Continent'])
plt.title("CONTINENT COUNT")
# Out:
# Text(0.5, 1.0, 'CONTINENT COUNT')

# %%
sns.histplot(x=ds['Continent'],color='yellow')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Count'>

# %%
sns.lineplot(data=ds,x=ds['National Income'],y=ds['Countries'],hue=ds['Continent'])
plt.title("INCOME ANALYSIS")
# Out:
# Text(0.5, 1.0, 'INCOME ANALYSIS')

# %%
sns.lineplot(data=ds,x=ds['Per person'],y=ds['Countries'],hue=ds['Continent'])
plt.title("PER PERSON ANALYSIS")
# Out:
# Text(0.5, 1.0, 'PER PERSON ANALYSIS')

# %%
sns.barplot(data=ds,x=ds['Per person'],y=ds['Countries'],hue=ds['Continent'])
plt.title('PER PERSON ANALYSIS')
# Out:
# Text(0.5, 1.0, 'PER PERSON ANALYSIS')

# %%
sns.barplot(data=ds,x=ds['2023'],y=ds['Countries'],hue=ds['Continent'])
plt.title('2023 ANALYSIS')
# Out:
# Text(0.5, 1.0, '2023 ANALYSIS')

# %%
sns.barplot(data=ds,x=ds['2023'],y=ds['Continent'],hue=ds['Countries'])
plt.title('2023 ANALYSIS')
# Out:
# Text(0.5, 1.0, '2023 ANALYSIS')
